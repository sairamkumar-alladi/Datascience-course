# %%
import pandas as pd

# %%
df = pd.read_csv('./tested.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
df1 = pd.read_csv('./tested.csv',nrows=5)

# %%
df1
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare  Cabin Embarked
# 0   330911   7.8292    NaN        Q
# 1   363272   7.0000    NaN        S
# 2   240276   9.6875    NaN        Q
# 3   315154   8.6625    NaN        S
# 4  3101298  12.2875    NaN        S

# %%
df2 = pd.read_csv('./tested.csv',usecols=['PassengerId',"Name","Survived"])

# %%
df2
# Out:
#      PassengerId  Survived                                          Name
# 0            892         0                              Kelly, Mr. James
# 1            893         1              Wilkes, Mrs. James (Ellen Needs)
# 2            894         0                     Myles, Mr. Thomas Francis
# 3            895         0                              Wirz, Mr. Albert
# 4            896         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...       ...                                           ...
# 413         1305         0                            Spector, Mr. Woolf
# 414         1306         1                  Oliva y Ocana, Dona. Fermina
# 415         1307         0                  Saether, Mr. Simon Sivertsen
# 416         1308         0                           Ware, Mr. Frederick
# 417         1309         0                      Peter, Master. Michael J
#
# [418 rows x 3 columns]

# %%
df3 = pd.read_csv('./tested.csv',usecols=[0,2,4,5])

# %%
df3
# Out:
#      PassengerId  Pclass     Sex   Age
# 0            892       3    male  34.5
# 1            893       3  female  47.0
# 2            894       2    male  62.0
# 3            895       3    male  27.0
# 4            896       3  female  22.0
# ..           ...     ...     ...   ...
# 413         1305       3    male   NaN
# 414         1306       1  female  39.0
# 415         1307       3    male  38.5
# 416         1308       3    male   NaN
# 417         1309       3    male   NaN
#
# [418 rows x 4 columns]

# %%
df4 = pd.read_csv('./tested.csv',skiprows=[2,4,5])

# %%
df4
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 0            892         0       3              Kelly, Mr. James    male
# 1            894         0       2     Myles, Mr. Thomas Francis    male
# 2            897         0       3    Svensson, Mr. Johan Cervin    male
# 3            898         1       3          Connolly, Miss. Kate  female
# 4            899         0       2  Caldwell, Mr. Albert Francis    male
# ..           ...       ...     ...                           ...     ...
# 410         1305         0       3            Spector, Mr. Woolf    male
# 411         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 412         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 413         1308         0       3           Ware, Mr. Frederick    male
# 414         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df5 = pd.read_csv('tested.csv',index_col='PassengerId')

# %%
df5
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
df7 = pd.read_csv('tested.csv',names=["col1","col2","col3","col4","col5"])
df7
# Out:
#                                                                                  col1  \
# PassengerId Survived Pclass Name                             Sex    Age  SibSp  Parch
# 892         0        3      Kelly, Mr. James                 male   34.5 0          0
# 893         1        3      Wilkes, Mrs. James (Ellen Needs) female 47   1          0
# 894         0        2      Myles, Mr. Thomas Francis        male   62   0          0
# 895         0        3      Wirz, Mr. Albert                 male   27   0          0
# ...                                                                               ...
# 1305        0        3      Spector, Mr. Woolf               male   NaN  0          0
# 1306        1        1      Oliva y Ocana, Dona. Fermina     female 39   0          0
# 1307        0        3      Saether, Mr. Simon Sivertsen     male   38.5 0          0
# 1308        0        3      Ware, Mr. Frederick              male   NaN  0          0
# ...

# %%
df7 = pd.read_csv('tested.csv',dtype={"Pclass":"float"})
df7
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0     3.0
# 1            893         1     3.0
# 2            894         0     2.0
# 3            895         0     3.0
# 4            896         1     3.0
# ..           ...       ...     ...
# 413         1305         0     3.0
# 414         1306         1     1.0
# 415         1307         0     3.0
# 416         1308         0     3.0
# 417         1309         0     3.0
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
