# %%
import pandas as pd

# %%
df = pd.read_csv('./tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # LOC --> (Stop index included & columns represented by names)
# - df.loc[rownumber]
# - df.loc[row_number,[column_name,...]]
# - df.loc[start:stop]
# - df.loc[start:stop,"column_name"]
# - df.loc[start:stop,["column_1,column_2...."]]
# - df.loc[start:stop,"column_1":"column_n"]

# %%
df.loc[0]
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
df.loc[3]
# Out:
# PassengerId                 895
# Survived                      0
# Pclass                        3
# Name           Wirz, Mr. Albert
# Sex                        male
# Age                        27.0
# SibSp                         0
# Parch                         0
# Ticket                   315154
# Fare                     8.6625
# Cabin                       NaN
# Embarked                      S
# Name: 3, dtype: object

# %%
type(df.loc[3])
# Out:
# pandas.core.series.Series

# %%
df.loc[3,['PassengerId','Survived','Name','Age','Sex']]
# Out:
# PassengerId                 895
# Survived                      0
# Name           Wirz, Mr. Albert
# Age                        27.0
# Sex                        male
# Name: 3, dtype: object

# %%
df.loc[3:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 3                               Wirz, Mr. Albert    male  27.0      0      0
# 4   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                     Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                           Connolly, Miss. Kate  female  30.0      0      0
# 7                   Caldwell, Mr. Albert Francis    male  26.0      1      1
# 8      Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 9                        Davies, Mr. John Samuel    male  21.0      2      0
# ...

# %%
df.loc[3:10,['PassengerId','Survived','Name','Age','Sex']]
# Out:
#     PassengerId  Survived                                          Name   Age  \
# 3           895         0                              Wirz, Mr. Albert  27.0
# 4           896         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# 5           897         0                    Svensson, Mr. Johan Cervin  14.0
# 6           898         1                          Connolly, Miss. Kate  30.0
# 7           899         0                  Caldwell, Mr. Albert Francis  26.0
# 8           900         1     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.0
# 9           901         0                       Davies, Mr. John Samuel  21.0
# 10          902         0                              Ilieff, Mr. Ylio   NaN
#
#        Sex
# 3     male
# 4   female
# 5     male
# 6   female
# 7     male
# 8   female
# 9     male
# 10    male

# %%
df.loc[1:12,'PassengerId':'SibSp']
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
#
#                                              Name     Sex   Age  SibSp
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                       Myles, Mr. Thomas Francis    male  62.0      0
# 3                                Wirz, Mr. Albert    male  27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0
# 6                            Connolly, Miss. Kate  female  30.0      0
# ...

# %%
df.loc[df["Survived"]==1,'PassengerId':'SibSp']
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df.loc[[1,5,3]]
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 5          897         0       3        Svensson, Mr. Johan Cervin    male
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 1  47.0      1      0  363272  7.0000   NaN        S
# 5  14.0      0      0    7538  9.2250   NaN        S
# 3  27.0      0      0  315154  8.6625   NaN        S

# %%
df.loc[:,'Pclass':]
# Out:
#      Pclass                                          Name     Sex   Age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male   NaN
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male   NaN
# 417       3                      Peter, Master. Michael J    male   NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # ILOC --> (Stop index included & columns represented by numbes)
# - df.iloc[rownumber]
# - df.iloc[row_number,column_num]
# - df.iloc[start:stop]
# - df.iloc[start:stop,"column_number"]
# - df.iloc[start:stop,["column_1,column_2...."]]
# - df.iloc[start:stop,"column_1":"column_n"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.iloc[1]
# Out:
# PassengerId                                 893
# Survived                                      1
# Pclass                                        3
# Name           Wilkes, Mrs. James (Ellen Needs)
# Sex                                      female
# Age                                        47.0
# SibSp                                         1
# Parch                                         0
# Ticket                                   363272
# Fare                                        7.0
# Cabin                                       NaN
# Embarked                                      S
# Name: 1, dtype: object

# %%
df.iloc[9]
# Out:
# PassengerId                        901
# Survived                             0
# Pclass                               3
# Name           Davies, Mr. John Samuel
# Sex                               male
# Age                               21.0
# SibSp                                2
# Parch                                0
# Ticket                       A/4 48871
# Fare                             24.15
# Cabin                              NaN
# Embarked                             S
# Name: 9, dtype: object

# %%
df.iloc[1,3]
# Out:
# 'Wilkes, Mrs. James (Ellen Needs)'

# %%
df.iloc[0:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# ...

# %%
df.iloc[0:6,1]
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
df.iloc[0:6,1:5]
# Out:
#    Survived  Pclass                                          Name     Sex
# 0         0       3                              Kelly, Mr. James    male
# 1         1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2         0       2                     Myles, Mr. Thomas Francis    male
# 3         0       3                              Wirz, Mr. Albert    male
# 4         1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5         0       3                    Svensson, Mr. Johan Cervin    male

# %%
df.iloc[[1,2,4,6],[3,4]]
# Out:
#                                            Name     Sex
# 1              Wilkes, Mrs. James (Ellen Needs)  female
# 2                     Myles, Mr. Thomas Francis    male
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 6                          Connolly, Miss. Kate  female
