# %%
import pandas as pd

# %%
# df = pd.read_csv('tested.csv',index_col="PassengerId")
df = pd.read_csv('tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# How many elements dataframe have
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.shape
# Out:
# (418, 12)

# %%
#df.loc[INDEX, COLUMNS]
df.loc[0]
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
df.loc[[1,2,8]]
# Out:
#    PassengerId  Survived  Pclass                                       Name  \
# 1          893         1       3           Wilkes, Mrs. James (Ellen Needs)
# 2          894         0       2                  Myles, Mr. Thomas Francis
# 8          900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 1  female  47.0      1      0  363272  7.0000   NaN        S
# 2    male  62.0      0      0  240276  9.6875   NaN        Q
# 8  female  18.0      0      0    2657  7.2292   NaN        C

# %%
df['Age'].max()
# Out:
# 76.0

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.sort_values(by=['Age'], ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 179         1071         1       1
# 236         1128         0       1
# 305         1197         1       1
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'] == 63
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
# Find the name of persons whose age is 63
df.loc[df['Age'] == 63]['Name']
# Out:
# 13                       Howard, Mr. Benjamin
# 114    Straus, Mrs. Isidor (Rosalie Ida Blun)
# Name: Name, dtype: object

# %%
len(df)
# Out:
# 418

# %%
for i in range(len(df)):
    if df.loc[i]['Age'] == 63:
        print(df.loc[i]['Name'])
# Out:
# Howard, Mr. Benjamin
# Straus, Mrs. Isidor (Rosalie Ida Blun)

# %%
df.loc[179]['Age']
# Out:
# 64.0

# %%
df.loc[0]
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
df['Age'].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
df['Age'].mode()
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
df['Age'].value_counts().head()
# Out:
# Age
# 24.0    17
# 21.0    17
# 22.0    16
# 30.0    15
# 18.0    13
# Name: count, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1425900/1069363814.py in ?()
# ----> 1 df.loc(df['Age'] == 63).tail()
#
# ~/CodingGrad/env/lib/python3.10/site-packages/pandas/core/indexing.py in ?(self, axis)
#     718         # we need to return a copy of ourselves
#     719         new_self = type(self)(self.name, self.obj)
#     720
#     721         if axis is not None:
# --> 722             axis_int_none = self.obj._get_axis_number(axis)
#     723         else:
#     724             axis_int_none = axis
#     725         new_self.axis = axis_int_none
#
# ~/CodingGrad/env/lib/python3.10/site-packages/pandas/core/generic.py in ?(cls, axis)
#     549     @classmethod
#     550     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     551         try:
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
# --> 553         except KeyError:
# ...
